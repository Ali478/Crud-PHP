# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali478/Crud-PHP/blob/master/ML_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DataSet Creation Hamza Mustafa,Asif Ahsan,Ali Murtaza,Mahrukh Rafique**

# %%
# !python -m pip install image_slicer
# Out:
# Collecting image_slicer
#   Downloading image_slicer-2.1.1-py2.py3-none-any.whl (8.3 kB)
# Collecting Pillow==7.2.0
#   Downloading Pillow-7.2.0-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 4.0 MB/s
# Installing collected packages: Pillow, image-slicer
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Pillow-7.2.0 image-slicer-2.1.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
from skimage.io import imread
import os
import matplotlib
import matplotlib.pyplot as plt
from pylab import *
import PIL
from PIL import Image
import glob, errno
import image_slicer
import numpy as np
import pandas as pd

# %%
Triangles=imread("/content/drive/MyDrive/triangle.jpg")
plt.figure()
imshow(Triangles)
plt.show()

# %%
print(Triangles, shape)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]] <function shape at 0x7f14ff1e0320>

# %%
import matplotlib.image as img
img = cv2.imread("/content/drive/MyDrive/triangle.jpg",0)
img.shape
# Out:
# (3448, 2414)

# %%
data = []
for col in range(0,img.shape[0],29):
    for row in range(0,img.shape[1],29):
        chunk = img[col:col+30,row:row+30]
        ls = chunk.flatten().tolist()
        if(len(ls)!=900):
            for i in range(len(ls),900):
                ls.append(0)
        data.append(ls)

# %%
df = pd.DataFrame(data)
df.to_csv("Triangle.csv")
df2 = pd.read_csv("Triangle.csv")
df2["Labels"] = "Triangle"
df2.to_csv("Triangle.csv", index=False)

# %%
df

# %%
Circles=imread("/content/drive/MyDrive/circle.jpg")
plt.figure()
imshow(Circles)
plt.show()

# %%
import matplotlib.image as imgc
imgc = cv2.imread("/content/drive/MyDrive/circle.jpg",0)
imgc.shape
# Out:
# (3447, 2440)

# %%
datacircle = []
for col in range(0,imgc.shape[0],29):
    for row in range(0,imgc.shape[1],29):
        chunk = imgc[col:col+30,row:row+30]
        ls = chunk.flatten().tolist()
        if(len(ls)!=900):
            for i in range(len(ls),900):
                ls.append(0)
        datacircle.append(ls)

# %%
df1 = pd.DataFrame(datacircle)
df1.to_csv("Circle.csv")
df2 = pd.read_csv("Circle.csv")
df2["Labels"] = "Circle"
df2.to_csv("Circle.csv", index=False)

# %%
df1

# %%
Squares=imread("/content/drive/MyDrive/square.jpg")
plt.figure()
imshow(Squares)
plt.show()

# %%
import matplotlib.image as imgsq
imgsq = cv2.imread("/content/drive/MyDrive/square.jpg",0)
imgsq.shape
# Out:
# (3434, 2424)

# %%
datasquare = []
for col in range(0,imgsq.shape[0],29):
    for row in range(0,imgsq.shape[1],29):
        chunk = imgsq[col:col+30,row:row+30]
        ls = chunk.flatten().tolist()
        if(len(ls)!=900):
            for i in range(len(ls),900):
                ls.append(0)
        datasquare.append(ls)

# %%
df2 = pd.DataFrame(datasquare)
df2.to_csv("Square.csv")
df2 = pd.read_csv("Square.csv")
df2["Labels"] = "Square"
df2.to_csv("Square.csv", index=False)
